# %% [markdown]
# ## **Project: Study On Panel Data Methodologies With Application To Macroeconometrics (Inflation Forecasting)**.
#
# > ### **Title**: Merge of Dataset.
#
#
# #### **Table of Contents:**
# <ul>
# <li><a href="#1">1. Delete countries with a large number of missing values.</a></li>
# <li><a href="#2">2. Delete years with a large number of missing values.</a></li>
# <li><a href="#3">3. Apply the interpolation to Missing Values.</a></li>
# </ul>

# %% [markdown]
# **Import Library**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import glob
import math


sns.set(rc={'figure.figsize': [15,5]}, font_scale=1.2);
pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# <a id=''></a>
#
# ### **Merge of Dataset:**
#
# #### 1.1.  Meta Data Tables:
# - > A. Table for `Countres` info: {'WEO_Country_Code', 'ISO', 'Country'} P_Key> 'WEO_Country_Code'.
# - > B. Table for `Subject` info: {'WEO_Subject_Code', 'Subject_Descriptor', 'Subject_Notes', 'Units', 'Scale'} P_Key>'WEO_Subject_Code'.
#
# - > C. Table for `Country_Subject_Notes` info: {'WEO_Country_Code', 'WEO_Subject_Code','Country_Series-specific_Notes','Estimates_Start_After'} P_Key>('WEO_Country_Code','WEO_Subject_Code').
# - > D. Table for `Year` info: {'Years'} P_Key> 'Years'.
#
# #### 1.2. dataset Tables:
#
# - > E. Table for data values `WEO_Data_Countries` name Columns {'WEO_Country_Code' , 'Years' , and all Varibles 'WEO_Subject_Code' {'BCA_NGDPD', 'GGR_NGDP', 'GGSB_NPGDP', 'GGX_NGDP', 'GGXWDG_NGDP', 'LUR', 'NGDP_RPCH', 'NGSD_NGDP', 'NID_NGDP', 'PCPIPCH', 'PPPEX', 'PPPPC', 'PPPSH', 'TM_RPCH', 'TRWMA', 'TX_RPCH'} }
#
# ----------------------------------------------
#
# #### 2.1.  Meta Data Tables:
# - > A. Table for `Country_Groups` info: {'WEO_Country_Group_Code', 'Country_Group_ID', 'Country_Group_Name'} P_Key> 'WEO_Country_Group_Code'.
# - > B. Table for `Groups_Subject_Notes` info: {'Weo_Country_Group_Code', 'WEO_Subject_Code', 'Country_Series-Specific_Notes', 'Estimates_Start_After'} P_Key> ('Weo_Country_Group_Code', 'Weo_Subject_Code').
#
# - > C. Table for `Country_Classes` info: {'Weo_Country_Code', 'Country', 'Weo_Country_Group_Code', and all Varibles 'Country_Group_ID' { 'All_Advanced_41','All_Advanced_Euro_20', 'All_Advanced_G7', 'All_Developing_155','All_Developing_Asia_30', 'All_Developing_Europe_15', 'All_Developing_Latina_Caribbean_33', 'All_Developing_Meast_Casia_32', 'All_Developing_Ssafrica_45', 'All_Asean_5', 'All_Brics_20', 'All_Eur_27'}}  P_Key> 'Weo_Country_Code'.
#
# #### 2.2. dataset Tables:
#
# - > D. Table for data values `Country_Data_Group`name Columns : {'WEO_Country_Group_Code' , 'Years' , and all Varibles 'WEO_Subject_Code' {'BCA_NGDPD', 'GGR_NGDP', 'GGSB_NPGDP', 'GGX_NGDP', 'GGXWDG_NGDP', 'LUR', 'NGDP_RPCH', 'NGSD_NGDP', 'NID_NGDP', 'PCPIPCH', 'PPPEX', 'PPPPC', 'PPPSH', 'TM_RPCH', 'TRWMA', 'TX_RPCH'}}
#
# -----------------------------------------------
#
# #### 3. Final Dataset Table:
#
# - > E. Table for data values `WEO_Data_Countries` name Columns {'WEO_Country_Code', 'Country', 'Advanced_Country', 'Years' , and all Varibles 'WEO_Subject_Code' {'BCA_NGDPD', 'GGR_NGDP', 'GGSB_NPGDP', 'GGX_NGDP', 'GGXWDG_NGDP', 'LUR', 'NGDP_RPCH', 'NGSD_NGDP', 'NID_NGDP', 'PCPIPCH', 'PPPEX', 'PPPPC', 'PPPSH', 'TM_RPCH', 'TRWMA', 'TX_RPCH'} }

# %% [markdown]
# **Path**

# %%
# Use glob to get a list of all files with the .csv extension
folder_path = "../03-Dataset/02-DataBase"
files_list = glob.glob(folder_path + "/*.csv")
files_list
# Out:
# ['../03-Dataset/02-DataBase\\01-Countries.csv',
#  '../03-Dataset/02-DataBase\\02-Subject.csv',
#  '../03-Dataset/02-DataBase\\03-Country_Subject_Notes.csv',
#  '../03-Dataset/02-DataBase\\04-Years.csv',
#  '../03-Dataset/02-DataBase\\05.1-WEO_Data_Countries.csv',
#  '../03-Dataset/02-DataBase\\05.2-WEO_Data_Countries.csv',
#  '../03-Dataset/02-DataBase\\06-Country_Groups.csv',
#  '../03-Dataset/02-DataBase\\07-Group_Subject_Notes.csv',
#  '../03-Dataset/02-DataBase\\08.1-Country_Classes.csv',
#  '../03-Dataset/02-DataBase\\08.2-Country_Classes.csv',
#  '../03-Dataset/02-DataBase\\08.3-Country_Classes.csv',
#  '../03-Dataset/02-DataBase\\09.1-Country_Data_Group.csv',
#  '../03-Dataset/02-DataBase\\09.2-Country_Data_Group.csv',
#  '../03-Dataset/02-DataBase\\10-WEO_Data.csv',
#  '../03-Dataset/02-DataBase\\10-WEO_Data_DB.csv']

# %% [markdown]
# **Load Dataset**

# %%
df = pd.read_csv(folder_path+"/10-WEO_Data.csv")
display(df.head())
# Out:
#    WEO_Country_Code        Country  Advanced_Country  Year  BCA_NGDPD  \
# 0               111  United States                 1  1980      0.081
# 1               111  United States                 1  1981      0.157
# 2               111  United States                 1  1982     -0.165
# 3               111  United States                 1  1983     -1.065
# 4               111  United States                 1  1984     -2.337
#
#    GGR_NGDP  GGSB_NPGDP  GGXWDG_NGDP  GGX_NGDP    LUR  NGDP_RPCH  NGSD_NGDP  \
# 0       NaN         NaN          NaN       NaN  7.175     -0.257     22.059
# 1       NaN         NaN          NaN       NaN  7.617      2.537     23.206
# 2       NaN         NaN          NaN       NaN  9.708     -1.803     21.713
# 3       NaN         NaN          NaN       NaN  9.600      4.584     19.725
# 4       NaN         NaN          NaN       NaN  7.508      7.236     21.839
#
#    NID_NGDP  PCPIPCH  PPPEX      PPPPC   PPPSH  TM_RPCH  TRWMA  TX_RPCH
# 0    23.310   13.502    1.0  12552.943  21.579   -6.664    NaN   10.778
# 1    24.277   10.378    1.0  13948.701  21.683    2.616    NaN    1.213
# 2    22.071    6.158    1.0  14404.994  21.185   -1.264    NaN   -7.662
# 3    22.253    3.160    1.0  15513.679  21.607   12.609    NaN   -2.589
# 4    25.096    4.368    1.0  17086.441  22.177   24.344    NaN    8.150

# %%
df.isna().sum()
# Out:
# WEO_Country_Code       0
# Country                0
# Advanced_Country       0
# Year                   0
# BCA_NGDPD           1182
# GGR_NGDP            2327
# GGSB_NPGDP          6304
# GGXWDG_NGDP         3049
# GGX_NGDP            2380
# LUR                 4681
# NGDP_RPCH            859
# NGSD_NGDP           1859
# NID_NGDP            1852
# PCPIPCH              906
# PPPEX                946
# PPPPC                901
# PPPSH                967
# TM_RPCH             1907
# TRWMA               5132
# TX_RPCH             1863
# dtype: int64

# %% [markdown]
# <a id='1'></a>
#
# ### **1. Delete countries with a large number of missing values:**

# %%
# List to store names of countries that meet the conditions
valid_countries = []

# Loop through each unique country to check the conditions
for country in df['Country'].unique():
    # Filter the data for the current country
    df_country = df[df['Country'] == country]
    
    # Drop columns that are not actual data variables
    data_only = df_country.drop(columns=['WEO_Country_Code', 'Country', 'Advanced_Country'])
    
    # Calculate the overall missing value ratio
    overall_missing_ratio = data_only.isnull().mean().mean()
    
    # Calculate the maximum missing ratio for any single variable
    max_missing_per_variable = data_only.isnull().mean().max()
    
    # If the country meets the criteria, add it to the list
    if overall_missing_ratio <= 0.5 and max_missing_per_variable <= 0.7:
        valid_countries.append(country)

# Create a new DataFrame containing only the accepted countries
filtered_df = df[df['Country'].isin(valid_countries)].copy()

# Display a summary of the new filtered data
print(f"Number of countries selected: {len(valid_countries)}")
print("Selected countries:", valid_countries)
# Out:
# Number of countries selected: 70
# Selected countries: ['United States', 'United Kingdom', 'Austria', 'Belgium', 'Denmark', 'France', 'Germany', 'Italy', 'Netherlands', 'Norway', 'Sweden', 'Switzerland', 'Canada', 'Japan', 'Finland', 'Greece', 'Iceland', 'Ireland', 'Malta', 'Portugal', 'Spain', 'Türkiye', 'Australia', 'New Zealand', 'South Africa', 'Argentina', 'Brazil', 'Chile', 'Colombia', 'Costa Rica', 'Dominican Republic', 'Ecuador', 'El Salvador', 'Mexico', 'Panama', 'Paraguay', 'Peru', 'Barbados', 'Suriname', 'Cyprus', 'Jordan', 'Egypt', 'Hong Kong SAR', 'Indonesia', 'Korea', 'Malaysia', 'Philippines', 'Singapore', 'Thailand', 'Mauritius', 'Morocco', 'Tunisia', 'Belarus', 'Georgia', 'Kazakhstan', 'Bulgaria', 'Russia', 'Ukraine', 'Czech Republic', 'Slovak Republic', 'Estonia', 'Latvia', 'Serbia', 'Hungary', 'Lithuania', 'Croatia', 'Slovenia', 'Bosnia and Herzegovina', 'Poland', 'Romania']

# %% [markdown]
# <a id='2'></a>
#
# ### **2. Delete years with a large number of missing values:**

# %%
# Get the list of valid countries from the filtered DataFrame
countries = filtered_df['Country'].unique()

# Set the number of columns in the subplot grid
cols = 5
rows = math.ceil(len(countries) / cols)  # Calculate number of required rows

# Create a figure and axes for subplots
fig, axes = plt.subplots(rows, cols, figsize=(cols * 4, rows * 3))
axes = axes.flatten()  # Flatten to easily index axes

for idx, country in enumerate(countries):
    # Filter the DataFrame for the current country
    df_country = filtered_df[filtered_df['Country'] == country]

    # Drop non-data columns
    data_only = df_country.drop(columns=['WEO_Country_Code', 'Country', 'Advanced_Country'])

    # Group by 'Year' and calculate missing value ratios for each variable
    missing_by_year = data_only.groupby(df_country['Year']) \
                               .apply(lambda x: x.drop(columns=['Year'], errors='ignore').isnull().mean())

    # Transpose for heatmap format
    missing_by_year = missing_by_year.T

    # Plot in the current subplot axis
    ax = axes[idx]
    sns.heatmap(
        missing_by_year,
        cmap='YlOrRd',
        linewidths=0.3,
        linecolor='gray',
        cbar=False,  # Hide color bar in each subplot to avoid clutter
        ax=ax
    )

    ax.set_title(country, fontsize=10)
    ax.set_xlabel('Year')
    ax.set_ylabel('Variables')

# Remove any unused axes
for j in range(len(countries), len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
plt.show()

# %%
filtered_df2 = filtered_df[filtered_df.Year.isin(np.arange(1995,2025))]
print(filtered_df2.shape)
filtered_df2.head()
# Out:
# (2100, 20)
#     WEO_Country_Code        Country  Advanced_Country  Year  BCA_NGDPD  \
# 15               111  United States                 1  1995     -1.487
# 16               111  United States                 1  1996     -1.546
# 17               111  United States                 1  1997     -1.641
# 18               111  United States                 1  1998     -2.373
# 19               111  United States                 1  1999     -2.976
#
#     GGR_NGDP  GGSB_NPGDP  GGXWDG_NGDP  GGX_NGDP    LUR  NGDP_RPCH  NGSD_NGDP  \
# 15       NaN         NaN          NaN       NaN  5.592      2.685     18.681
# 16       NaN         NaN          NaN       NaN  5.408      3.773     19.570
# 17       NaN         NaN          NaN       NaN  4.942      4.447     20.773
# 18       NaN         NaN          NaN       NaN  4.500      4.483     21.315
# 19       NaN         NaN          NaN       NaN  4.217      4.788     20.851
#
#     NID_NGDP  PCPIPCH  PPPEX      PPPPC   PPPSH  TM_RPCH  TRWMA  TX_RPCH
# 15    21.273    2.805    1.0  28671.480  20.007    8.000   2.94   10.277
# 16    21.702    2.937    1.0  29946.973  20.006    8.698   2.86    8.174
# 17    22.410    2.338    1.0  31440.087  20.083   13.465   2.60   11.908
# 18    22.958    1.547    1.0  32833.666  20.446   11.690   3.09    2.338
# 19    23.419    2.193    1.0  34496.241  20.704   11.595   2.31    4.980

# %%
filtered_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2100 entries, 15 to 8774
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   WEO_Country_Code  2100 non-null   int64
#  1   Country           2100 non-null   object
#  2   Advanced_Country  2100 non-null   int64
#  3   Year              2100 non-null   int64
#  4   BCA_NGDPD         2091 non-null   float64
#  5   GGR_NGDP          2039 non-null   float64
#  6   GGSB_NPGDP        1886 non-null   float64
#  7   GGXWDG_NGDP       1990 non-null   float64
#  8   GGX_NGDP          2028 non-null   float64
#  9   LUR               2091 non-null   float64
#  10  NGDP_RPCH         2086 non-null   float64
#  11  NGSD_NGDP         2095 non-null   float64
#  12  NID_NGDP          2094 non-null   float64
#  13  PCPIPCH           2085 non-null   float64
#  14  PPPEX             2092 non-null   float64
#  15  PPPPC             2094 non-null   float64
#  16  PPPSH             2094 non-null   float64
#  17  TM_RPCH           2087 non-null   float64
#  18  TRWMA             1648 non-null   float64
#  19  TX_RPCH           2086 non-null   float64
# dtypes: float64(16), int64(3), object(1)
# memory usage: 344.5+ KB

# %%
filtered_df2.isna().sum()
# Out:
# WEO_Country_Code      0
# Country               0
# Advanced_Country      0
# Year                  0
# BCA_NGDPD             9
# GGR_NGDP             61
# GGSB_NPGDP          214
# GGXWDG_NGDP         110
# GGX_NGDP             72
# LUR                   9
# NGDP_RPCH            14
# NGSD_NGDP             5
# NID_NGDP              6
# PCPIPCH              15
# PPPEX                 8
# PPPPC                 6
# PPPSH                 6
# TM_RPCH              13
# TRWMA               452
# TX_RPCH              14
# dtype: int64

# %% [markdown]
# <a id='3'></a>
#
# ### **3. Apply the interpolation to Missing Values:**

# %%
# columns that missing values
cols_with_na = filtered_df2.columns[filtered_df2.isnull().any()].tolist()
cols_with_na
# Out:
# ['BCA_NGDPD',
#  'GGR_NGDP',
#  'GGSB_NPGDP',
#  'GGXWDG_NGDP',
#  'GGX_NGDP',
#  'LUR',
#  'NGDP_RPCH',
#  'NGSD_NGDP',
#  'NID_NGDP',
#  'PCPIPCH',
#  'PPPEX',
#  'PPPPC',
#  'PPPSH',
#  'TM_RPCH',
#  'TRWMA',
#  'TX_RPCH']

# %%
# Sort the data by Country and Year (panel structure)
df_panel = filtered_df2.sort_values(by=['Country', 'Year']).copy()

# Drop non-numeric and identifier columns
df_numeric = df_panel.drop(columns=['WEO_Country_Code', 'Country', 'Advanced_Country', 'Year'])

# Select numeric columns
data_columns = df_numeric.columns
data_columns
# Out:
# Index(['BCA_NGDPD', 'GGR_NGDP', 'GGSB_NPGDP', 'GGXWDG_NGDP', 'GGX_NGDP', 'LUR',
#        'NGDP_RPCH', 'NGSD_NGDP', 'NID_NGDP', 'PCPIPCH', 'PPPEX', 'PPPPC',
#        'PPPSH', 'TM_RPCH', 'TRWMA', 'TX_RPCH'],
#       dtype='object')

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge

# Copy 
df_panel_b = df_panel.copy()

# Handle missing values for each country 
def handle_missing_country(country):
    imputer = IterativeImputer(estimator=BayesianRidge(), max_iter=20, random_state=0, verbose=2)
    country[cols_with_na] = imputer.fit_transform(country[cols_with_na])
    return country

# Apply
df_interpolated = df_panel_b.groupby('Country', group_keys=False).apply(handle_missing_country)
# Out:
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.10
# [IterativeImputer] Change: 43.734734479349385, scaled tolerance: 29.335855
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.19
# [IterativeImputer] Change: 0.01382870565858596, scaled tolerance: 29.335855
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 4.762354248664032, scaled tolerance: 69.475413
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 0.94316154559588, scaled tolerance: 73.050854
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 9.071185430779128, scaled tolerance: 22.03488
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 172.18771196722204, scaled tolerance: 32.098475
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.08
# [IterativeImputer] Change: 24.72493057922118, scaled tolerance: 32.098475
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 1.0524291845450935, scaled tolerance: 73.221637
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.05
# [IterativeImputer] Change: 15286.17338316333, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.10
# [IterativeImputer] Change: 1591.7792064377234, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 3/20, elapsed time 0.15
# [IterativeImputer] Change: 634.1959706768635, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 4/20, elapsed time 0.20
# [IterativeImputer] Change: 398.52397160123354, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 5/20, elapsed time 0.25
# [IterativeImputer] Change: 292.89693426314886, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 6/20, elapsed time 0.29
# [IterativeImputer] Change: 243.4118894911407, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 7/20, elapsed time 0.33
# [IterativeImputer] Change: 213.88387362019708, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 8/20, elapsed time 0.37
# [IterativeImputer] Change: 191.4006805028888, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 9/20, elapsed time 0.41
# [IterativeImputer] Change: 172.4465959118034, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 10/20, elapsed time 0.46
# [IterativeImputer] Change: 155.8019029932737, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 11/20, elapsed time 0.50
# [IterativeImputer] Change: 140.92843866383498, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 12/20, elapsed time 0.54
# [IterativeImputer] Change: 127.53779075348606, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 13/20, elapsed time 0.58
# [IterativeImputer] Change: 115.44379620304431, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 14/20, elapsed time 0.62
# [IterativeImputer] Change: 104.5061913905866, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 15/20, elapsed time 0.66
# [IterativeImputer] Change: 94.60870100609115, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 16/20, elapsed time 0.70
# [IterativeImputer] Change: 85.6501435746627, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 17/20, elapsed time 0.74
# [IterativeImputer] Change: 77.54049681239671, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 18/20, elapsed time 0.78
# [IterativeImputer] Change: 70.19893405406233, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 19/20, elapsed time 0.81
# [IterativeImputer] Change: 63.55245672229233, scaled tolerance: 21.498089
# [IterativeImputer] Ending imputation round 20/20, elapsed time 0.85
# [IterativeImputer] Change: 57.535123449751055, scaled tolerance: 21.498089
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.05
# [IterativeImputer] Change: 34.587438698622435, scaled tolerance: 22.122709999999998
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.08
# [IterativeImputer] Change: 4.237542064813393, scaled tolerance: 22.122709999999998
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 1181.7662623585816, scaled tolerance: 39.185322
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.07
# [IterativeImputer] Change: 169.69328868665048, scaled tolerance: 39.185322
# [IterativeImputer] Ending imputation round 3/20, elapsed time 0.10
# [IterativeImputer] Change: 37.249514682379285, scaled tolerance: 39.185322
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 0.9752783640099633, scaled tolerance: 62.765568
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.05
# [IterativeImputer] Change: 6.396360123092664, scaled tolerance: 33.574404
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 27.438223516296013, scaled tolerance: 21.436901000000002
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.08
# [IterativeImputer] Change: 1.116316969191816, scaled tolerance: 21.436901000000002
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 6.241429952626776, scaled tolerance: 29.779185000000002
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.05
# [IterativeImputer] Change: 30.285588009235223, scaled tolerance: 48.811093
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 6.8761101218417595, scaled tolerance: 59.857876
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.05
# [IterativeImputer] Change: 10.424366263775571, scaled tolerance: 56.686216
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 1.1105377635440004, scaled tolerance: 83.454418
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 22.498946565092368, scaled tolerance: 28.949585
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 37.69151700092346, scaled tolerance: 16.515535
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.08
# [IterativeImputer] Change: 9.413674981351141, scaled tolerance: 16.515535
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 20.481650699001015, scaled tolerance: 20.799054
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 4.683474039544256, scaled tolerance: 13.17275
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 3.2331106932152234, scaled tolerance: 48.00804
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 0.9639626495647047, scaled tolerance: 64.65733800000001
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 1.0439154488751083, scaled tolerance: 65.940409
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 45.8313146551926, scaled tolerance: 27.363366000000003
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.08
# [IterativeImputer] Change: 12.565330737958142, scaled tolerance: 27.363366000000003
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 0.8678388163460924, scaled tolerance: 70.930357
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 0.9840832619448987, scaled tolerance: 42.06572
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 5.956439781166982, scaled tolerance: 75.40684200000001
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 10.32175840389983, scaled tolerance: 46.807165000000005
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 2.078114808850418, scaled tolerance: 78.808044
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 102.04336201477705, scaled tolerance: 16.542109
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.07
# [IterativeImputer] Change: 67.33694330637219, scaled tolerance: 16.542109
# [IterativeImputer] Ending imputation round 3/20, elapsed time 0.11
# [IterativeImputer] Change: 0.0033389537769199507, scaled tolerance: 16.542109
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 0.8999431965310305, scaled tolerance: 131.94974200000001
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 1.2190197210718634, scaled tolerance: 60.992864000000004
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 2.895635513494325, scaled tolerance: 53.059360000000005
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 12.407536025140418, scaled tolerance: 10.916507
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.07
# [IterativeImputer] Change: 0.15214246438827317, scaled tolerance: 10.916507
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 26.768246846878945, scaled tolerance: 41.366311
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 4.970050634777275, scaled tolerance: 62.96047
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 32.54900775607102, scaled tolerance: 43.526926
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 24.537107384026786, scaled tolerance: 53.623635
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 1.9744482073846625, scaled tolerance: 41.021961000000005
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 11.063098731447184, scaled tolerance: 72.941905
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 12.810338819027901, scaled tolerance: 32.062706
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 9.376144410445779, scaled tolerance: 24.971323
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 18.025315352283435, scaled tolerance: 10.61506
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.07
# [IterativeImputer] Change: 0.8699057806867954, scaled tolerance: 10.61506
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 0.9479614753761312, scaled tolerance: 81.49462799999999
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 2.3624010333742658, scaled tolerance: 52.983046
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 0.866461285936897, scaled tolerance: 103.44604
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 7.230706721375855, scaled tolerance: 41.292258000000004
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 10.804704978748513, scaled tolerance: 16.64223
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 29.53612343140736, scaled tolerance: 17.775180000000002
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.07
# [IterativeImputer] Change: 4.791517582238644, scaled tolerance: 17.775180000000002
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 4.68818715914847, scaled tolerance: 12.079571
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 11.91931697990438, scaled tolerance: 51.628831
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 0.8372422826141537, scaled tolerance: 49.236504000000004
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 51.651738315908304, scaled tolerance: 47.203733
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.08
# [IterativeImputer] Change: 5.786815390740765, scaled tolerance: 47.203733
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 266.14631278195566, scaled tolerance: 47.298706
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.08
# [IterativeImputer] Change: 9.126497336957703, scaled tolerance: 47.298706
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 1520.8360964392389, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.09
# [IterativeImputer] Change: 1418.0056949840275, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 3/20, elapsed time 0.14
# [IterativeImputer] Change: 693.9041168651706, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 4/20, elapsed time 0.18
# [IterativeImputer] Change: 559.7837828665073, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 5/20, elapsed time 0.22
# [IterativeImputer] Change: 401.1004768722223, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 6/20, elapsed time 0.27
# [IterativeImputer] Change: 254.2165944948633, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 7/20, elapsed time 0.32
# [IterativeImputer] Change: 153.3809234701837, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 8/20, elapsed time 0.36
# [IterativeImputer] Change: 105.54415267311957, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 9/20, elapsed time 0.41
# [IterativeImputer] Change: 106.43265735205135, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 10/20, elapsed time 0.45
# [IterativeImputer] Change: 105.53333715700936, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 11/20, elapsed time 0.50
# [IterativeImputer] Change: 103.1961151444751, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 12/20, elapsed time 0.55
# [IterativeImputer] Change: 99.71962102403256, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 13/20, elapsed time 0.59
# [IterativeImputer] Change: 105.40284261241865, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 14/20, elapsed time 0.63
# [IterativeImputer] Change: 109.41394679543535, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 15/20, elapsed time 0.67
# [IterativeImputer] Change: 109.53436358310086, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 16/20, elapsed time 0.72
# [IterativeImputer] Change: 106.96647540542871, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 17/20, elapsed time 0.76
# [IterativeImputer] Change: 102.60520492148207, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 18/20, elapsed time 0.81
# [IterativeImputer] Change: 97.11165763376032, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 19/20, elapsed time 0.85
# [IterativeImputer] Change: 90.96954570870419, scaled tolerance: 29.038902
# [IterativeImputer] Ending imputation round 20/20, elapsed time 0.89
# [IterativeImputer] Change: 84.52843461395992, scaled tolerance: 29.038902
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 0.6106973023167155, scaled tolerance: 148.185776
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.03
# [IterativeImputer] Change: 2.7176273277457383, scaled tolerance: 45.632207
# [IterativeImputer] Early stopping criterion reached.
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 4.1198704702347575, scaled tolerance: 55.683968
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 36.26813881215763, scaled tolerance: 15.723251000000001
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.07
# [IterativeImputer] Change: 11.793394705545488, scaled tolerance: 15.723251000000001
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 0.9327350003581185, scaled tolerance: 55.089205
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.11
# [IterativeImputer] Change: 9.325355896413987, scaled tolerance: 21.403829
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.06
# [IterativeImputer] Change: 1.179784670310918, scaled tolerance: 71.730789
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 3.5372144565835444, scaled tolerance: 95.836636
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 22.57085561798951, scaled tolerance: 25.211769
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 18.00726927742453, scaled tolerance: 14.338485
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.09
# [IterativeImputer] Change: 0.16106814289138605, scaled tolerance: 14.338485
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.05
# [IterativeImputer] Change: 42.710142892541086, scaled tolerance: 40.283307
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.11
# [IterativeImputer] Change: 5.901859772544672, scaled tolerance: 40.283307
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 193.53528761613654, scaled tolerance: 19.603124
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.09
# [IterativeImputer] Change: 5.897253625908483, scaled tolerance: 19.603124
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.04
# [IterativeImputer] Change: 1.245259743573083, scaled tolerance: 62.573612000000004
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (30, 16)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.06
# [IterativeImputer] Change: 33.64942338301097, scaled tolerance: 86.60128
# [IterativeImputer] Early stopping criterion reached.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23996\1897214877.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_interpolated = df_panel_b.groupby('Country', group_keys=False).apply(handle_missing_country)

# %%
df_interpolated.isna().sum()
# Out:
# WEO_Country_Code    0
# Country             0
# Advanced_Country    0
# Year                0
# BCA_NGDPD           0
# GGR_NGDP            0
# GGSB_NPGDP          0
# GGXWDG_NGDP         0
# GGX_NGDP            0
# LUR                 0
# NGDP_RPCH           0
# NGSD_NGDP           0
# NID_NGDP            0
# PCPIPCH             0
# PPPEX               0
# PPPPC               0
# PPPSH               0
# TM_RPCH             0
# TRWMA               0
# TX_RPCH             0
# dtype: int64

# %%
# Select the country
country_name = 'Serbia'#'Belarus'  # Change this as needed

# Columns to interpolate (already defined earlier)
# data_columns = [col for col in filtered_df2.columns if col not in ['WEO_Country_Code', 'Country', 'Advanced_Country', 'Year']]

# Filter data before and after interpolation
before = filtered_df2[filtered_df2['Country'] == country_name]
after = df_interpolated[df_interpolated['Country'] == country_name]

# Create subplots
n_cols = 3
n_rows = (len(data_columns) + n_cols - 1) // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows * 4), constrained_layout=True)

for i, col in enumerate(data_columns):
    row, col_idx = divmod(i, n_cols)
    ax = axes[row, col_idx]

    ax.plot(before['Year'], before[col], 'o-', label='Before interpolation', color='red')
    ax.plot(after['Year'], after[col], '--', label='After interpolation', color='green')

    ax.set_title(f'{col} over Years in {country_name}', fontsize=10)
    ax.set_xlabel('Year')
    ax.set_ylabel(col)
    ax.legend()
    ax.grid(True)

# Hide any unused subplots
for j in range(len(data_columns), n_rows * n_cols):
    fig.delaxes(axes.flatten()[j])

# Main title
plt.suptitle(f'Time Series of All Variables for {country_name} (Before and After Interpolation)', fontsize=14)
plt.show()

# %%
df_interpolated.to_csv(folder_path+"/../01-Data_Clean.csv",index=False)

# %% [markdown]
# # **END**
