# %% [markdown]
# ## **Project: Study On Panel Data Methodologies With Application To Macroeconometrics (Inflation Forecasting)**.
#
# > ### **Title**: Merge of Dataset.
#
#
# #### **Table of Contents:**
# <ul>
# <li><a href="#1">1. Dataset Description and Variable Overview.</a></li>
# <li><a href="#2">2. Descriptive Analysis.</a></li>
# <li><a href="#3">3. Visualization And Correlation Analysis.</a></li>
# </ul>

# %% [markdown]
# <a id='1'></a>
#
# ### **1. Dataset Description and Variable Overview:**
#
# The dataset includes annual macroeconomic data for  **70 countries** over the period **2000–2024**. Most variables are sourced from the **IMF’s World Economic Outlook (WEO)**, except **TRWMA**, which is derived from the **World Bank**. The target variable is **PCPIPCH** (Inflation, average consumer prices). Below is the list of variables used:
#
# | **Variable Code** | **Description**                                    | **Units**                                         |
# | ----------------- | -------------------------------------------------- | ------------------------------------------------- |
# | Country_Code      | ID number for each country                         | ID                                                |
# | Country           | Name of 70 countries                               | String                                            |
# | Advanced_Country  | Is the country developed (1) or developing (0)?    | Boolean                                           |
# | Years             | date from 2000 to 2024                             | Date                                              |
# | NGDP_RPCH         | Gross domestic product, constant prices            | Percent change                                    |
# | PPPPC             | Gross domestic product per capita, current prices  | Purchasing power parity; international dollars    |
# | PPPSH             | Gross domestic product based on purchasing-power-parity (PPP) share of world total | Percent           |
# | NGSD_NGDP         | Gross national savings                             | Percent of GDP                                    |
# | NID_NGDP          | Total investment                                   | Percent of GDP                                    |
# | PPPEX             | Implied PPP conversion rate                        | National currency per current international dollar|
# | TX_RPCH           | Volume of exports of goods and services            | Percent change                                    |
# | TM_RPCH           | Volume of imports of goods and services            | Percent change                                    |
# | LUR               | Unemployment rate                                  | Percent of total labor force                      |
# | GGR_NGDP          | General government revenue                         | Percent of GDP                                    |
# | GGX_NGDP          | General government total expenditure               | Percent of GDP                                    |
# | GGSB_NPGDP        | General government structural balance              | Percent of potential GDP                          |
# | GGXWDG_NGDP       | General government gross debt                      | Percent of GDP                                    |
# | BCA_NGDPD         | Current account balance                            | Percent of GDP                                    |
# | TRWMA             | Tariff rate, applied, weighted mean, all products  | Percent                                           |
# | **PCPIPCH**       | Inflation, average consumer prices `(Target)`      | Percent change                                    |
#
#
# ---

# %% [markdown]
# #### **1. Inflation & Price Stability (التضخم واستقرار الأسعار)**
#
# | Variable Code    | Term             | التفسير |                تأثيره على التضخم                                            |
# | ---------------- | ---------------- | --------------------------------- | --------------------------------------------------- |
# | **PCPIPCH**   | Inflation (CPI) | معدل التضخم بناءً على متوسط أسعار المستهلكين؛ مؤشر رئيسي لاستقرار الأسعار. | المتغير الهدف، ويقيس بشكل مباشر مدى ارتفاع الأسعار. |
#
# ---
#
# #### **2. Public Finance (المالية العامة)**
#
# | Variable Code    | Term             | التفسير |                تأثيره على التضخم                                            |
# | ---------------- | ---------------- | --------------------------------- | --------------------------------------------------- |
# | **GGR_NGDP**    | Government Revenue (% of GDP)     | إيرادات الحكومة كنسبة من الناتج؛ تشمل الضرائب والإيرادات الأخرى.       | الإيرادات المرتفعة قد تخفف التضخم من خلال تقليص الطلب الكلي.              |
# | **GGX_NGDP**    | Government Expenditure (% of GDP) | نفقات الحكومة كنسبة من الناتج؛ تشمل الإنفاق على الخدمات العامة والدعم. | زيادة الإنفاق الحكومي قد تؤدي إلى زيادة التضخم من خلال رفع الطلب الكلي.   |
# | **GGSB_NPGDP**  | Structural Budget Balance         | الميزان الهيكلي بعد خصم أثر الدورة الاقتصادية.                         | الفائض الهيكلي يُعتبر إشارة إلى سياسة مالية انكماشية تقلل من التضخم.      |
# | **GGXWDG_NGDP** | Gross Government Debt (% of GDP)  | الدين العام كنسبة من الناتج؛ يعكس عبء الحكومة المالي.                  | ارتفاع الدين قد يُجبر الحكومة على التوسع النقدي مستقبلاً مما يزيد التضخم. |
#
#
# ---
#
#
# #### **3. Economic Output & Productivity (الإنتاجية والناتج الاقتصادي)**
#
# | Variable Code    | Term             | التفسير |                تأثيره على التضخم                                            |
# | ---------------- | ---------------- | --------------------------------- | --------------------------------------------------- |
# | **NGDP_RPCH** | Real GDP Growth        | معدل نمو الناتج المحلي الإجمالي الحقيقي، يعكس النشاط الاقتصادي. | النمو المرتفع قد يؤدي إلى تضخم إذا زاد الطلب الكلي أكثر من العرض.                  |
# | **PPPPC**      | GDP per Capita (PPP)   | نصيب الفرد من الناتج باستخدام تعادل القوة الشرائية.             | ارتفاعه يشير إلى قدرة شرائية أعلى، ما قد يدفع بالأسعار إلى الارتفاع.               |
# | **PPPSH**      | PPP Share of World GDP | حصة الدولة من الناتج العالمي حسب القوة الشرائية.                | تأثير غير مباشر؛ يعكس القوة الاقتصادية النسبية والتي قد تؤثر على تدفقات رأس المال. |
#
# ---
#
# #### **4. Exchange & Purchasing Power (سعر الصرف والقوة الشرائية)**
#
# | Variable Code    | Term             | التفسير |                تأثيره على التضخم                                            |
# | ---------------- | ---------------- | --------------------------------- | --------------------------------------------------- |
# | **PPPEX**     | PPP Conversion Factor | معدل التحويل على أساس تعادل القوة الشرائية. | انخفاض قيمة العملة المحلية مقابل الدولار قد يزيد من تكلفة الاستيراد وبالتالي التضخم. |
#
# ---
#
# #### **5. International Trade & Balance (التجارة الدولية والحساب الجاري)**
#
# | Variable Code    | Term             | التفسير |                تأثيره على التضخم                                            |
# | ---------------- | ---------------- | --------------------------------- | --------------------------------------------------- |
# | **TX_RPCH**   | Export Volume Growth            | نمو حجم الصادرات.                   | زيادة الصادرات قد تقلل المعروض المحلي وترفع الأسعار.                |
# | **TM_RPCH**   | Import Volume Growth            | نمو حجم الواردات.                   | زيادة الواردات توفر بدائل أرخص وتقلل من التضخم.                     |
# | **BCA_NGDPD** | Current Account Balance (% GDP) | رصيد الحساب الجاري كنسبة من الناتج. | فائض الحساب الجاري يعكس تدفق عملات أجنبية مما يدعم استقرار الأسعار. |
# | **TRWMA**      | Weighted Tariff Rate            | متوسط الرسوم الجمركية المطبقة.      | الرسوم العالية على الواردات ترفع الأسعار وتزيد التضخم.              |
#
# ---
#
# #### **6. Savings & Investment (الادخار والاستثمار)**
#
# | Variable Code    | Term             | التفسير |                تأثيره على التضخم                                            |
# | ---------------- | ---------------- | --------------------------------- | --------------------------------------------------- |
# | **NGSD_NGDP** | Gross National Savings  | الادخار الوطني كنسبة من الناتج.     | ارتفاع الادخار يقلل من الاستهلاك وبالتالي يقلل الضغط التضخمي. |
# | **NID_NGDP**  | Gross Capital Formation | الاستثمار الإجمالي كنسبة من الناتج. | استثمار أكبر قد يرفع الإنتاج في الأجل الطويل مما يقلل التضخم. |
#
# ---
#
# #### **7. Labor Market Indicators (سوق العمل)**
#
# | Variable Code    | Term             | التفسير |                تأثيره على التضخم                                            |
# | ---------------- | ---------------- | --------------------------------- | --------------------------------------------------- |
# | **LUR**       | Unemployment Rate | معدل البطالة كنسبة من القوة العاملة. | انخفاض البطالة قد يرفع الأجور وبالتالي الأسعار، مما يزيد التضخم. |
#
# ---
#
# #### **8. Country Metadata (بيانات الدول)**
#
# | Variable Code    | Term             | التفسير |                تأثيره على التضخم                                            |
# | ---------------- | ---------------- | --------------------------------- | --------------------------------------------------- |
# | **Country_Code**     | Country ID         | معرف رقمي فريد لكل دولة. | -                 |
# | **Country**           | Country Name       | اسم الدولة.              | -                 |
# | **Advanced_Country** | Development Status | متقدمة (1) أو نامية (0). | -                 |
# | **Years**             | Year               | السنة ما بين 2000 و2024. | -                 |
#
# ---

# %% [markdown]
# **Import Library**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
from statsmodels.nonparametric.smoothers_lowess import lowess

import glob
import math


sns.set(rc={'figure.figsize': [15,5]}, font_scale=1.2);
pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# **Load Dataset**

# %%
folder_path = "../02-Dataset"

df1 = pd.read_csv(folder_path + "/01.1-Data_Clean.csv")
print(df1.shape)
display(df1.head())
# Out:
# (1750, 20)
#    WEO_Country_Code    Country  Advanced_Country  Year  BCA_NGDPD  GGR_NGDP  \
# 0               213  Argentina                 0  2000     -2.878    21.830
# 1               213  Argentina                 0  2001     -1.316    21.068
# 2               213  Argentina                 0  2002      7.666    19.943
# 3               213  Argentina                 0  2003      5.597    23.526
# 4               213  Argentina                 0  2004      1.798    26.996
#
#    GGSB_NPGDP  GGXWDG_NGDP  GGX_NGDP     LUR  NGDP_RPCH  NGSD_NGDP  NID_NGDP  \
# 0      -4.552       40.833    25.247  17.134     -0.789     12.459    15.337
# 1      -5.590       48.007    26.432  19.209     -4.409     12.325    13.640
# 2       1.188      147.203    21.853  22.450    -10.894     17.631     9.965
# 3       3.453      125.162    22.026  17.250      8.955     18.474    12.877
# 4       4.719      117.878    23.030  13.625      8.911     19.350    17.551
#
#    PCPIPCH  PPPEX      PPPPC  PPPSH  TM_RPCH  TRWMA  TX_RPCH
# 0   -0.939  0.639  13529.290  0.995   -2.322  10.52    1.898
# 1   -1.065  0.618  13091.488  0.929  -16.587   9.25    6.096
# 2   25.869  0.794  11733.021  0.806  -53.558  12.01    0.244
# 3   13.443  0.859  12914.244  0.847   48.953  12.87    5.006
# 4    4.416  0.887  14308.616  0.878   51.050   5.96   -0.150

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1750 entries, 0 to 1749
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   WEO_Country_Code  1750 non-null   int64
#  1   Country           1750 non-null   object
#  2   Advanced_Country  1750 non-null   int64
#  3   Year              1750 non-null   int64
#  4   BCA_NGDPD         1750 non-null   float64
#  5   GGR_NGDP          1750 non-null   float64
#  6   GGSB_NPGDP        1750 non-null   float64
#  7   GGXWDG_NGDP       1750 non-null   float64
#  8   GGX_NGDP          1750 non-null   float64
#  9   LUR               1750 non-null   float64
#  10  NGDP_RPCH         1750 non-null   float64
#  11  NGSD_NGDP         1750 non-null   float64
#  12  NID_NGDP          1750 non-null   float64
#  13  PCPIPCH           1750 non-null   float64
#  14  PPPEX             1750 non-null   float64
#  15  PPPPC             1750 non-null   float64
#  16  PPPSH             1750 non-null   float64
#  17  TM_RPCH           1750 non-null   float64
#  18  TRWMA             1750 non-null   float64
#  19  TX_RPCH           1750 non-null   float64
# dtypes: float64(16), int64(3), object(1)
# memory usage: 273.6+ KB

# %%
df1.isna().sum()
# Out:
# WEO_Country_Code    0
# Country             0
# Advanced_Country    0
# Year                0
# BCA_NGDPD           0
# GGR_NGDP            0
# GGSB_NPGDP          0
# GGXWDG_NGDP         0
# GGX_NGDP            0
# LUR                 0
# NGDP_RPCH           0
# NGSD_NGDP           0
# NID_NGDP            0
# PCPIPCH             0
# PPPEX               0
# PPPPC               0
# PPPSH               0
# TM_RPCH             0
# TRWMA               0
# TX_RPCH             0
# dtype: int64

# %% [markdown]
# **Conclusion:**
# The dataset contains 1,750 rows and 20 columns with no missing values. All columns are fully populated, and the data types are appropriate for analysis, including numerical and categorical variables. The dataset clean and ready for analysis.
#
# -------------------------------

# %% [markdown]
# <a id='2'></a>
#
# ### **2. Descriptive Analysis:**

# %%
# Reorder columns based on priority to control inflation
# (Ensure column names match exactly what exists in your DataFrame)

ordered_columns = [
    # 8. Metadata
    "Country", "Advanced_Country", "Year",
    
    # 1. Inflation & Price Stability
    "PCPIPCH",  # Inflation Rate (Consumer Prices, annual %)
    
    # 2. Public Finance
    "GGR_NGDP",     # General government revenue (% of GDP)
    "GGX_NGDP",     # General government expenditure (% of GDP)
    "GGSB_NPGDP",   # General government structural balance
    "GGXWDG_NGDP",  # General government gross debt (% of GDP)
    
    # 3. Economic Output & Productivity
    "NGDP_RPCH",    # Real GDP growth (%)
    "PPPPC",        # GDP per capita based on PPP
    "PPPSH",        # PPP share of world total
    
    # 4. Exchange & Purchasing Power
    "PPPEX",        # PPP exchange rate
    
    # 5. International Trade & Balance
    "TX_RPCH",      # Export volume growth
    "TM_RPCH",      # Import volume growth
    "BCA_NGDPD",    # Current account balance (% of GDP)
    "TRWMA",        # World trade volume (goods and services)
    
    # 6. Savings & Investment
    "NGSD_NGDP",    # Net government saving (% of GDP)
    "NID_NGDP",     # Investment (% of GDP)
    
    # 7. Labor Market
    "LUR"           # Unemployment rate (%)
]

# Apply the new column order to the DataFrame
df = df1[ordered_columns]

# Display the first 5 rows to confirm new order
display(df.head())
# Out:
#      Country  Advanced_Country  Year  PCPIPCH  GGR_NGDP  GGX_NGDP  GGSB_NPGDP  \
# 0  Argentina                 0  2000   -0.939    21.830    25.247      -4.552
# 1  Argentina                 0  2001   -1.065    21.068    26.432      -5.590
# 2  Argentina                 0  2002   25.869    19.943    21.853       1.188
# 3  Argentina                 0  2003   13.443    23.526    22.026       3.453
# 4  Argentina                 0  2004    4.416    26.996    23.030       4.719
#
#    GGXWDG_NGDP  NGDP_RPCH      PPPPC  PPPSH  PPPEX  TX_RPCH  TM_RPCH  \
# 0       40.833     -0.789  13529.290  0.995  0.639    1.898   -2.322
# 1       48.007     -4.409  13091.488  0.929  0.618    6.096  -16.587
# 2      147.203    -10.894  11733.021  0.806  0.794    0.244  -53.558
# 3      125.162      8.955  12914.244  0.847  0.859    5.006   48.953
# 4      117.878      8.911  14308.616  0.878  0.887   -0.150   51.050
#
#    BCA_NGDPD  TRWMA  NGSD_NGDP  NID_NGDP     LUR
# 0     -2.878  10.52     12.459    15.337  17.134
# 1     -1.316   9.25     12.325    13.640  19.209
# 2      7.666  12.01     17.631     9.965  22.450
# 3      5.597  12.87     18.474    12.877  17.250
# 4      1.798   5.96     19.350    17.551  13.625

# %%
df.describe().T
# Out:
#                    count          mean           std          min  \
# Advanced_Country  1750.0      0.485714      0.499939     0.000000
# Year              1750.0   2012.000000      7.213164  2000.000000
# PCPIPCH           1750.0      5.184262     10.767512    -3.723000
# GGR_NGDP          1750.0     33.217403     11.166926    12.352000
# GGX_NGDP          1750.0     35.573582     11.403711     9.015000
# GGSB_NPGDP        1750.0     -2.436963      3.193499   -21.489000
# GGXWDG_NGDP       1750.0     57.392399     36.698413     0.052000
# NGDP_RPCH         1750.0      2.922613      3.817213   -28.759000
# PPPPC             1750.0  29144.158285  19788.011279  3230.470000
# PPPSH             1750.0      0.978094      2.224212     0.003000
# PPPEX             1750.0    130.889777    550.005941     0.016000
# TX_RPCH           1750.0      4.598294      8.978500   -57.613000
# TM_RPCH           1750.0      4.834027     10.116378   -53.558000
# BCA_NGDPD         1750.0     -0.866469      6.099047   -24.068000
# TRWMA             1750.0      3.813529      3.618103    -4.055915
# NGSD_NGDP         1750.0     22.541346      8.167286   -76.451000
# NID_NGDP          1750.0     23.482843      5.602739     8.932000
# LUR               1750.0      8.486300      5.322983     0.700000
#
#                           25%           50%          75%            max
# Advanced_Country      0.00000      0.000000      1.00000       1.000000
# Year               2006.00000   2012.000000   2018.00000    2024.000000
# PCPIPCH               1.55300      2.861500      5.56125     229.824000
# GGR_NGDP             23.32075     33.980000     41.55625      63.053000
# GGX_NGDP             25.92925     36.373500     44.58225      74.416000
# GGSB_NPGDP           -4.31925     -2.234000     -0.36275      11.137000
# GGXWDG_NGDP          35.63825     49.732500     71.78250     258.374000
# NGDP_RPCH             1.36825      2.986031      4.98775      24.616000
# PPPPC             13391.98575  24488.918000  40951.29300  148185.776000
# PPPSH                 0.09700      0.343500      0.92350      20.502000
# PPPEX                 0.65225      1.266500      9.80675    4917.825000
# TX_RPCH               0.74400      4.306500      8.87975      72.658000
# TM_RPCH               0.30450      4.959500      9.99550      68.477698
# BCA_NGDPD            -4.33800     -1.359000      2.15750      30.165000
# TRWMA                 1.72000      2.320000      4.61521      26.380000
# NGSD_NGDP            17.82300     22.146500     26.64525      60.788000
# NID_NGDP             19.97900     22.865500     25.86625      68.207000
# LUR                   5.02400      7.173500     10.06275      34.300000

# %%
df.Country.value_counts()
# Out:
# Country
# Argentina        25
# Netherlands      25
# Philippines      25
# Peru             25
# Paraguay         25
#                  ..
# Iceland          25
# Indonesia        25
# Ireland          25
# Italy            25
# United States    25
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# **Conclusion:**
# **Temporal Coverage:**
# - The variable `Year` ranges from **2000 to 2024**, with a mean and median of **2012**, showing evenly distributed temporal data.
#
# **Economic Indicators:**
# - `BCA_NGDPD` (Current account balance as % of GDP) has a **wide range** (-24.07 to 30.17), with a **mean of -0.87**, suggesting many countries have deficits.
# - `GGR_NGDP` and `GGX_NGDP` indicate **government revenue and expenditure** as % of GDP, averaging around **33.2%** and **35.6%**, respectively.
#
# **Fiscal Balance and Debt:**
# - `GGSB_NPGDP` (General government structural balance) averages **-2.44%**, showing a general fiscal deficit trend.
# - `GGXWDG_NGDP` (General government gross debt) varies significantly (0.05% to 258.37%), with a high **standard deviation (36.69%)**, indicating disparities in national debt levels.
#
# **Unemployment and Growth:**
# - `LUR` (unemployment rate) ranges from **0.7% to 34.3%**, with a mean of **8.49%**.
# - `NGDP_RPCH` (real GDP growth) and `PCPIPCH` (inflation) also show **wide variations**, reflecting different economic cycles and inflationary pressures across countries.
#
# **Purchasing Power and Price Indices:**
# - `PPPPC` (GDP per capita in PPP terms) has a **very high standard deviation (19,788)**, indicating significant income disparities.
# - `PPPEX`, `PPPSH`, and `PPPCIPCH` reflect major variations in purchasing power and price level adjustments across countries.
#
# **Trade Indicators:**
# - `TM_RPCH` and `TX_RPCH` (import and export growth rates) show **large ranges**, with both negative and positive extremes, suggesting varied trade performance globally.
# - `TRWMA` (world market share of exports) varies up to **26.38**, though average participation is relatively low (**3.76**), reflecting a few dominant export nations.
#
# **Country Distribution:**
# - Each of the 70 countries contributes **exactly 25 records**, confirming a **consistent and complete data structure** suitable for comparative analysis.
#
# ----------------------------------

# %% [markdown]
# <a id='3'></a>
#
# ### **3. Visualization And Correlation Analysis:**

# %%
# Get the unique list of countries in the dataset
selected_countries = df["Country"].unique()

# Display the list of selected countries
print("Unique countries in dataset:")
print(selected_countries)
# Out:
# Unique countries in dataset:
# ['Argentina' 'Australia' 'Austria' 'Barbados' 'Belarus' 'Belgium'
#  'Bosnia and Herzegovina' 'Brazil' 'Bulgaria' 'Canada' 'Chile' 'Colombia'
#  'Costa Rica' 'Croatia' 'Cyprus' 'Czech Republic' 'Denmark'
#  'Dominican Republic' 'Ecuador' 'Egypt' 'El Salvador' 'Estonia' 'Finland'
#  'France' 'Georgia' 'Germany' 'Greece' 'Hong Kong SAR' 'Hungary' 'Iceland'
#  'Indonesia' 'Ireland' 'Italy' 'Japan' 'Jordan' 'Kazakhstan' 'Korea'
#  'Latvia' 'Lithuania' 'Malaysia' 'Malta' 'Mauritius' 'Mexico' 'Morocco'
#  'Netherlands' 'New Zealand' 'Norway' 'Panama' 'Paraguay' 'Peru'
#  'Philippines' 'Poland' 'Portugal' 'Romania' 'Russia' 'Serbia' 'Singapore'
#  'Slovak Republic' 'Slovenia' 'South Africa' 'Spain' 'Suriname' 'Sweden'
#  'Switzerland' 'Thailand' 'Tunisia' 'Türkiye' 'Ukraine' 'United Kingdom'
#  'United States']

# %%
# Compute correlation matrices
corr_all = df.drop(columns=["Country"]).corr("spearman")
corr_dev = df[df["Advanced_Country"] == 0].drop(columns=["Country", "Advanced_Country"]).corr("spearman")
corr_adv = df[df["Advanced_Country"] == 1].drop(columns=["Country", "Advanced_Country"]).corr("spearman")
corr_eg = df[df["Country"] == "Egypt"].drop(columns=["Country", "Advanced_Country"]).corr()
corr_us = df[df["Country"] == "United States"].drop(columns=["Country", "Advanced_Country"]).corr()
corr_bz = df[df["Country"] == "Brazil"].drop(columns=["Country", "Advanced_Country"]).corr()
corr_uk = df[df["Country"] == "United Kingdom"].drop(columns=["Country", "Advanced_Country"]).corr()

# List of matrices with titles
matrices = [
    ("All Countries", corr_all),
    ("Developing Countries", corr_dev),
    ("Advanced Countries", corr_adv),
    ("Egypt", corr_eg),
    ("United States", corr_us),
    ("Brazil", corr_bz),
    ("United Kingdom", corr_uk)
]

# Create figure and gridspec: 3 rows, 2 columns
fig = plt.figure(figsize=(29, 27))
gs = GridSpec(4, 2, figure=fig)

# First heatmap takes full width (row 0, all columns)
ax1 = fig.add_subplot(gs[0, :])
mask = np.triu(np.ones_like(matrices[0][1], dtype=bool))
sns.heatmap(matrices[0][1], mask=mask, annot=True, fmt=".2f", cmap="coolwarm", cbar=False, annot_kws={"size": 19}, ax=ax1)
ax1.set_title(matrices[0][0])

# Plot remaining 4 heatmaps in a 2x2 grid (rows 1 and 2, cols 0 and 1)
for i, (title, matrix) in enumerate(matrices[1:], start=1):
    row = 1 + (i - 1) // 2  # row 1 or 2
    col = (i - 1) % 2       # col 0 or 1
    ax = fig.add_subplot(gs[row, col])
    mask = np.triu(np.ones_like(matrix, dtype=bool))
    sns.heatmap(matrix, mask=mask, annot=True, fmt=".2f", cmap="coolwarm", cbar=False, annot_kws={"size": 17}, ax=ax)
    ax.set_title(title)

plt.tight_layout()
plt.show()

# %%
X_vars = [
    # 2. Public Finance
    #"GGR_NGDP",     ## General government revenue (% of GDP)
    #"GGX_NGDP",     ## General government expenditure (% of GDP)
    "GGSB_NPGDP",   ## General government structural balance
    "GGXWDG_NGDP",  # General government gross debt (% of GDP)
    
    # 3. Economic Output & Productivity
    #"NGDP_RPCH",    ## Real GDP growth (%)
    "PPPPC",        # GDP per capita based on PPP
    #"PPPSH",        ## PPP share of world total
    
    # 4. Exchange & Purchasing Power
    #"PPPEX",        # PPP exchange rate
    
    # 5. International Trade & Balance
    "TX_RPCH",      # Export volume growth
    "TM_RPCH",      ## Import volume growth
    #"BCA_NGDPD",    # Current account balance (% of GDP)
    #"TRWMA",        ## World trade volume (goods and services)
    
    # 6. Savings & Investment
    #"NGSD_NGDP",    ## Net government saving (% of GDP)
    "NID_NGDP",     # Investment (% of GDP)
    
    # 7. Labor Market
    #"LUR"           # Unemployment rate (%)
]

# %%
# ===============================
# Multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
X = df[X_vars]

X_np = X.values

vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X_np, i) for i in range(X_np.shape[1])]

print(vif_data)
# Out:
#        feature       VIF
# 0   GGSB_NPGDP  1.752526
# 1  GGXWDG_NGDP  3.403836
# 2        PPPPC  3.457779
# 3      TX_RPCH  2.082648
# 4      TM_RPCH  2.119305
# 5     NID_NGDP  4.473428

# %%
# ===============================
# VIF per Country

# # Dictionary to store VIF results per country
# vif_by_country = {}

# # Loop over each country group
# for country_name, group in df.groupby('Country'):
#     X = group[X_vars]

#     # Check: Enough rows to compute VIF (must be > number of variables)
#         # and avoid constant columns
#     if X.shape[0] > len(X_vars) and X.nunique().min() > 1:
#         try:
#             X_np = X.values
#             vif_data = pd.DataFrame()
#             vif_data["feature"] = X.columns
#             vif_data["VIF"] = [variance_inflation_factor(X_np, i) for i in range(X_np.shape[1])]
#             vif_by_country[country_name] = vif_data
#         except Exception as e:
#             print(f"Failed to compute VIF for {country_name}: {e}")
#     else:
#         print(f"Skipped {country_name}: insufficient data for VIF.")

# # Example: Print or export VIF for Country
# cty = "Egypt"
# print(f"VIF for {cty}:")
# print(vif_by_country.get(cty))


# cty_df = df[df['Country'] == cty]
# corr = cty_df[X_vars].corr()

# plt.figure(figsize=(12, 10))
# sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
# plt.title(f'Correlation Matrix - {cty}')
# plt.show()

# %%
df1.head()
# Out:
#    WEO_Country_Code    Country  Advanced_Country  Year  BCA_NGDPD  GGR_NGDP  \
# 0               213  Argentina                 0  2000     -2.878    21.830
# 1               213  Argentina                 0  2001     -1.316    21.068
# 2               213  Argentina                 0  2002      7.666    19.943
# 3               213  Argentina                 0  2003      5.597    23.526
# 4               213  Argentina                 0  2004      1.798    26.996
#
#    GGSB_NPGDP  GGXWDG_NGDP  GGX_NGDP     LUR  NGDP_RPCH  NGSD_NGDP  NID_NGDP  \
# 0      -4.552       40.833    25.247  17.134     -0.789     12.459    15.337
# 1      -5.590       48.007    26.432  19.209     -4.409     12.325    13.640
# 2       1.188      147.203    21.853  22.450    -10.894     17.631     9.965
# 3       3.453      125.162    22.026  17.250      8.955     18.474    12.877
# 4       4.719      117.878    23.030  13.625      8.911     19.350    17.551
#
#    PCPIPCH  PPPEX      PPPPC  PPPSH  TM_RPCH  TRWMA  TX_RPCH
# 0   -0.939  0.639  13529.290  0.995   -2.322  10.52    1.898
# 1   -1.065  0.618  13091.488  0.929  -16.587   9.25    6.096
# 2   25.869  0.794  11733.021  0.806  -53.558  12.01    0.244
# 3   13.443  0.859  12914.244  0.847   48.953  12.87    5.006
# 4    4.416  0.887  14308.616  0.878   51.050   5.96   -0.150

# %%
# Reorder columns based on priority to control inflation
# (Ensure column names match exactly what exists in your DataFrame)

ordered_columns = [
    # 8. Metadata
    "WEO_Country_Code", "Country", "Advanced_Country", "Year",
    
    # 1. Inflation & Price Stability
    "PCPIPCH",  # Inflation Rate (Consumer Prices, annual %)
    
    # 2. Public Finance
    "GGSB_NPGDP",   # General government structural balance
    "GGXWDG_NGDP",  # General government gross debt (% of GDP)
    
    # 3. Economic Output & Productivity & Exchange & Purchasing Power
    "PPPPC",        # GDP per capita based on PPP
    
    # 4. Exchange & Purchasing Power
    
    # 5. International Trade & Balance
    "TX_RPCH",      # Export volume growth
    "TM_RPCH",      # Import volume growth

    # 6. Savings & Investment
    "NID_NGDP",     # Investment (% of GDP)
    
]

# Apply the new column order to the DataFrame
df2 = df1[ordered_columns]

# Display the first 5 rows to confirm new order
display(df2.head())
# Out:
#    WEO_Country_Code    Country  Advanced_Country  Year  PCPIPCH  GGSB_NPGDP  \
# 0               213  Argentina                 0  2000   -0.939      -4.552
# 1               213  Argentina                 0  2001   -1.065      -5.590
# 2               213  Argentina                 0  2002   25.869       1.188
# 3               213  Argentina                 0  2003   13.443       3.453
# 4               213  Argentina                 0  2004    4.416       4.719
#
#    GGXWDG_NGDP      PPPPC  TX_RPCH  TM_RPCH  NID_NGDP
# 0       40.833  13529.290    1.898   -2.322    15.337
# 1       48.007  13091.488    6.096  -16.587    13.640
# 2      147.203  11733.021    0.244  -53.558     9.965
# 3      125.162  12914.244    5.006   48.953    12.877
# 4      117.878  14308.616   -0.150   51.050    17.551

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1750 entries, 0 to 1749
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   WEO_Country_Code  1750 non-null   int64
#  1   Country           1750 non-null   object
#  2   Advanced_Country  1750 non-null   int64
#  3   Year              1750 non-null   int64
#  4   PCPIPCH           1750 non-null   float64
#  5   GGSB_NPGDP        1750 non-null   float64
#  6   GGXWDG_NGDP       1750 non-null   float64
#  7   PPPPC             1750 non-null   float64
#  8   TX_RPCH           1750 non-null   float64
#  9   TM_RPCH           1750 non-null   float64
#  10  NID_NGDP          1750 non-null   float64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 150.5+ KB

# %%
df2.to_csv(folder_path+"/01.2-Data_Clean.csv",index=False)

# %% [markdown]
# # **END**
