# %% [markdown]
# ## **Project: Study On Panel Data Methodologies With Application To Macroeconometrics (Inflation Forecasting)**.
#
# > ### **Title**: Merge of Dataset.
#
#
# #### **Table of Contents:**
# <ul>
# <li><a href="#1">1. select Country(`Rgypt`, `United States`):</a></li>
# <li><a href="#2">2. Handling Missing Values:</a></li>
# </ul>

# %% [markdown]
# **Import Library**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import glob
import math


sns.set(rc={'figure.figsize': [15,5]}, font_scale=1.2);
pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# <a id=''></a>
#
# ### **Merge of Dataset:**
#
# #### 1.1.  Meta Data Tables:
# - > A. Table for `Countres` info: {'WEO_Country_Code', 'ISO', 'Country'} P_Key> 'WEO_Country_Code'.
# - > B. Table for `Subject` info: {'WEO_Subject_Code', 'Subject_Descriptor', 'Subject_Notes', 'Units', 'Scale'} P_Key>'WEO_Subject_Code'.
#
# - > C. Table for `Country_Subject_Notes` info: {'WEO_Country_Code', 'WEO_Subject_Code','Country_Series-specific_Notes','Estimates_Start_After'} P_Key>('WEO_Country_Code','WEO_Subject_Code').
# - > D. Table for `Year` info: {'Years'} P_Key> 'Years'.
#
# #### 1.2. dataset Tables:
#
# - > E. Table for data values `WEO_Data_Countries` name Columns {'WEO_Country_Code' , 'Years' , and all Varibles 'WEO_Subject_Code' {'BCA_NGDPD', 'GGR_NGDP', 'GGSB_NPGDP', 'GGX_NGDP', 'GGXWDG_NGDP', 'LUR', 'NGDP_RPCH', 'NGSD_NGDP', 'NID_NGDP', 'PCPIPCH', 'PPPEX', 'PPPPC', 'PPPSH', 'TM_RPCH', 'TRWMA', 'TX_RPCH'} }
#
# ----------------------------------------------
#
# #### 2.1.  Meta Data Tables:
# - > A. Table for `Country_Groups` info: {'WEO_Country_Group_Code', 'Country_Group_ID', 'Country_Group_Name'} P_Key> 'WEO_Country_Group_Code'.
# - > B. Table for `Groups_Subject_Notes` info: {'Weo_Country_Group_Code', 'WEO_Subject_Code', 'Country_Series-Specific_Notes', 'Estimates_Start_After'} P_Key> ('Weo_Country_Group_Code', 'Weo_Subject_Code').
#
# - > C. Table for `Country_Classes` info: {'Weo_Country_Code', 'Country', 'Weo_Country_Group_Code', and all Varibles 'Country_Group_ID' { 'All_Advanced_41','All_Advanced_Euro_20', 'All_Advanced_G7', 'All_Developing_155','All_Developing_Asia_30', 'All_Developing_Europe_15', 'All_Developing_Latina_Caribbean_33', 'All_Developing_Meast_Casia_32', 'All_Developing_Ssafrica_45', 'All_Asean_5', 'All_Brics_20', 'All_Eur_27'}}  P_Key> 'Weo_Country_Code'.
#
# #### 2.2. dataset Tables:
#
# - > D. Table for data values `Country_Data_Group`name Columns : {'WEO_Country_Group_Code' , 'Years' , and all Varibles 'WEO_Subject_Code' {'BCA_NGDPD', 'GGR_NGDP', 'GGSB_NPGDP', 'GGX_NGDP', 'GGXWDG_NGDP', 'LUR', 'NGDP_RPCH', 'NGSD_NGDP', 'NID_NGDP', 'PCPIPCH', 'PPPEX', 'PPPPC', 'PPPSH', 'TM_RPCH', 'TRWMA', 'TX_RPCH'}}
#
# -----------------------------------------------
#
# #### 3. Final Dataset Table:
#
# - > E. Table for data values `WEO_Data_Countries` name Columns {'WEO_Country_Code', 'Country', 'Advanced_Country', 'Years' , and all Varibles 'WEO_Subject_Code' {'BCA_NGDPD', 'GGR_NGDP', 'GGSB_NPGDP', 'GGX_NGDP', 'GGXWDG_NGDP', 'LUR', 'NGDP_RPCH', 'NGSD_NGDP', 'NID_NGDP', 'PCPIPCH', 'PPPEX', 'PPPPC', 'PPPSH', 'TM_RPCH', 'TRWMA', 'TX_RPCH'} }

# %% [markdown]
# **Path**

# %%
# Use glob to get a list of all files with the .csv extension
folder_path = "../02-Dataset/02-DataBase"
files_list = glob.glob(folder_path + "/*.csv")
files_list
# Out:
# ['../03-Dataset/02-DataBase\\01-Countries.csv',
#  '../03-Dataset/02-DataBase\\02-Subject.csv',
#  '../03-Dataset/02-DataBase\\03-Country_Subject_Notes.csv',
#  '../03-Dataset/02-DataBase\\04-Years.csv',
#  '../03-Dataset/02-DataBase\\05.1-WEO_Data_Countries.csv',
#  '../03-Dataset/02-DataBase\\05.2-WEO_Data_Countries.csv',
#  '../03-Dataset/02-DataBase\\06-Country_Groups.csv',
#  '../03-Dataset/02-DataBase\\07-Group_Subject_Notes.csv',
#  '../03-Dataset/02-DataBase\\08.1-Country_Classes.csv',
#  '../03-Dataset/02-DataBase\\08.2-Country_Classes.csv',
#  '../03-Dataset/02-DataBase\\08.3-Country_Classes.csv',
#  '../03-Dataset/02-DataBase\\09.1-Country_Data_Group.csv',
#  '../03-Dataset/02-DataBase\\09.2-Country_Data_Group.csv',
#  '../03-Dataset/02-DataBase\\10-WEO_Data.csv',
#  '../03-Dataset/02-DataBase\\10-WEO_Data_DB.csv']

# %% [markdown]
# **Load Dataset**

# %%
df = pd.read_csv(folder_path+"/10-WEO_Data.csv")
display(df.head())
# Out:
#    WEO_Country_Code        Country  Advanced_Country  Year  BCA_NGDPD  \
# 0               111  United States                 1  1980      0.081
# 1               111  United States                 1  1981      0.157
# 2               111  United States                 1  1982     -0.165
# 3               111  United States                 1  1983     -1.065
# 4               111  United States                 1  1984     -2.337
#
#    GGR_NGDP  GGSB_NPGDP  GGXWDG_NGDP  GGX_NGDP    LUR  NGDP_RPCH  NGSD_NGDP  \
# 0       NaN         NaN          NaN       NaN  7.175     -0.257     22.059
# 1       NaN         NaN          NaN       NaN  7.617      2.537     23.206
# 2       NaN         NaN          NaN       NaN  9.708     -1.803     21.713
# 3       NaN         NaN          NaN       NaN  9.600      4.584     19.725
# 4       NaN         NaN          NaN       NaN  7.508      7.236     21.839
#
#    NID_NGDP  PCPIPCH  PPPEX      PPPPC   PPPSH  TM_RPCH  TRWMA  TX_RPCH
# 0    23.310   13.502    1.0  12552.943  21.579   -6.664    NaN   10.778
# 1    24.277   10.378    1.0  13948.701  21.683    2.616    NaN    1.213
# 2    22.071    6.158    1.0  14404.994  21.185   -1.264    NaN   -7.662
# 3    22.253    3.160    1.0  15513.679  21.607   12.609    NaN   -2.589
# 4    25.096    4.368    1.0  17086.441  22.177   24.344    NaN    8.150

# %%
df.isna().sum()
# Out:
# WEO_Country_Code       0
# Country                0
# Advanced_Country       0
# Year                   0
# BCA_NGDPD           1182
# GGR_NGDP            2327
# GGSB_NPGDP          6304
# GGXWDG_NGDP         3049
# GGX_NGDP            2380
# LUR                 4681
# NGDP_RPCH            859
# NGSD_NGDP           1859
# NID_NGDP            1852
# PCPIPCH              906
# PPPEX                946
# PPPPC                901
# PPPSH                967
# TM_RPCH             1907
# TRWMA               5132
# TX_RPCH             1863
# dtype: int64

# %% [markdown]
# <a id='1'></a>
#
# ### **1. select Country(`Rgypt`, `United States`):**

# %%
df_eu = df[(df["Country"]=="Egypt") | (df["Country"]=="United States")]
df_eu.sample(10)
# Out:
#       WEO_Country_Code        Country  Advanced_Country  Year  BCA_NGDPD  \
# 3356               469          Egypt                 0  2006      1.552
# 3366               469          Egypt                 0  2016     -5.643
# 20                 111  United States                 1  2000     -3.921
# 3336               469          Egypt                 0  1986     -2.759
# 8                  111  United States                 1  1988     -2.314
# 2                  111  United States                 1  1982     -0.165
# 3333               469          Egypt                 0  1983     -3.974
# 34                 111  United States                 1  2014     -2.102
# 7                  111  United States                 1  1987     -3.309
# 30                 111  United States                 1  2010     -2.871
#
#       GGR_NGDP  GGSB_NPGDP  GGXWDG_NGDP  GGX_NGDP     LUR  NGDP_RPCH  \
# 3356    27.186      -8.695       85.924    34.540  10.917      6.844
# 3366    19.172     -11.397       91.586    30.968  12.705      4.340
# 20         NaN         NaN          NaN       NaN   3.967      4.078
# 3336       NaN         NaN          NaN       NaN     NaN      4.759
# 8          NaN         NaN          NaN       NaN   5.492      4.177
# 2          NaN         NaN          NaN       NaN   9.708     -1.803
# 3333       NaN         NaN          NaN       NaN     NaN      8.876
# 34      31.298      -3.696      104.242    35.324   6.158      2.524
# 7          NaN         NaN          NaN       NaN   6.175      3.455
# 30      28.770     -10.078       95.162    39.763   9.608      2.695
#
#       NGSD_NGDP  NID_NGDP  PCPIPCH  PPPEX      PPPPC   PPPSH  TM_RPCH  TRWMA  \
# 3356     24.655    23.104    4.292  1.061   8475.096   0.840   15.214  10.05
# 3366     11.802    17.445   10.212  2.633  11952.822   0.929    5.360   6.63
# 20       20.741    23.678    3.367  1.000  36312.782  20.502   13.000   2.10
# 3336      8.089    22.614   23.900  0.225   3522.618   0.821    0.807    NaN
# 8        20.564    22.828    4.100  1.000  21375.999  22.205    3.932    NaN
# 2        21.713    22.071    6.158  1.000  14404.994  21.185   -1.264    NaN
# 3333     12.967    28.791   15.982  0.205   2883.125   0.755    3.118    NaN
# 34       19.571    20.901    1.615  1.000  55263.817  16.325    5.160   1.69
# 7        19.548    23.620    3.578  1.000  20000.968  22.252    5.937    NaN
# 30       15.288    18.672    1.637  1.000  48586.288  17.165   12.968   1.66
#
#       TX_RPCH
# 3356    8.019
# 3366   -6.492
# 20      8.312
# 3336    0.627
# 8      16.212
# 2      -7.662
# 3333    1.987
# 34      3.902
# 7      10.929
# 30     12.647

# %%
df_eu.isna().sum()
# Out:
# WEO_Country_Code     0
# Country              0
# Advanced_Country     0
# Year                 0
# BCA_NGDPD            0
# GGR_NGDP            40
# GGSB_NPGDP          47
# GGXWDG_NGDP         39
# GGX_NGDP            40
# LUR                 10
# NGDP_RPCH            0
# NGSD_NGDP            0
# NID_NGDP             0
# PCPIPCH              0
# PPPEX                0
# PPPPC                0
# PPPSH                0
# TM_RPCH              0
# TRWMA               34
# TX_RPCH              0
# dtype: int64

# %%
# Get the list of valid countries from the filtered DataFrame
countries = df_eu['Country'].unique()


# Create a figure and axes for subplots
fig, axes = plt.subplots(1, 2, figsize=(17, 7))
axes = axes.flatten()  # Flatten to easily index axes

for idx, country in enumerate(countries):
    # Filter the DataFrame for the current country
    df_country = df_eu[df_eu['Country'] == country]

    # Drop non-data columns
    data_only = df_country.drop(columns=['WEO_Country_Code', 'Country', 'Advanced_Country'])

    # Group by 'Year' and calculate missing value ratios for each variable
    missing_by_year = data_only.groupby(df_country['Year']) \
                               .apply(lambda x: x.drop(columns=['Year'], errors='ignore').isnull().mean())

    # Transpose for heatmap format
    missing_by_year = missing_by_year.T

    # Plot in the current subplot axis
    ax = axes[idx]
    sns.heatmap(
        missing_by_year,
        cmap='YlOrRd',
        linewidths=0.3,
        linecolor='gray',
        cbar=False,  # Hide color bar in each subplot to avoid clutter
        ax=ax
    )

    ax.set_title(country, fontsize=10)
    ax.set_xlabel('Year')
    ax.set_ylabel('Variables')

# Remove any unused axes
for j in range(len(countries), len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id='2'></a>
#
# ### **2. Handling Missing Values:**

# %%
# Sort the data by Country and Year (panel structure)
df_eu_p = df_eu.sort_values(by=['Country', 'Year']).copy()

# columns that missing values
cols_with_na = ['GGR_NGDP', 'GGSB_NPGDP', 'GGXWDG_NGDP', 'GGX_NGDP', 'LUR', 'TRWMA']

# Drop non-numeric and identifier columns
df_numeric = df_eu_p.drop(columns=['WEO_Country_Code', 'Country', 'Advanced_Country', 'Year'])

# Select numeric columns
data_columns = df_numeric.columns
data_columns
# Out:
# Index(['BCA_NGDPD', 'GGR_NGDP', 'GGSB_NPGDP', 'GGXWDG_NGDP', 'GGX_NGDP', 'LUR',
#        'NGDP_RPCH', 'NGSD_NGDP', 'NID_NGDP', 'PCPIPCH', 'PPPEX', 'PPPPC',
#        'PPPSH', 'TM_RPCH', 'TRWMA', 'TX_RPCH'],
#       dtype='object')

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge

# Copy 
df_eu_p_b = df_eu_p.copy()

# Handle missing values for each country 
def handle_missing_country(country):
    imputer = IterativeImputer(estimator=BayesianRidge(), max_iter=20, random_state=0, verbose=2)
    country[cols_with_na] = imputer.fit_transform(country[cols_with_na])
    return country

# Apply
df_handled = df_eu_p_b.groupby('Country', group_keys=False).apply(handle_missing_country)
# Out:
# [IterativeImputer] Completing matrix with shape (45, 6)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.02
# [IterativeImputer] Change: 6.441151571806536, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.05
# [IterativeImputer] Change: 1.8721693696589359, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 3/20, elapsed time 0.07
# [IterativeImputer] Change: 0.4503125545323208, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 4/20, elapsed time 0.09
# [IterativeImputer] Change: 0.40705080222396184, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 5/20, elapsed time 0.11
# [IterativeImputer] Change: 0.37055134439404647, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 6/20, elapsed time 0.12
# [IterativeImputer] Change: 0.326654471020257, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 7/20, elapsed time 0.14
# [IterativeImputer] Change: 0.2813179753260844, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 8/20, elapsed time 0.16
# [IterativeImputer] Change: 0.23872303177432563, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 9/20, elapsed time 0.17
# [IterativeImputer] Change: 0.1997497577249252, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 10/20, elapsed time 0.19
# [IterativeImputer] Change: 0.17768616218582522, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 11/20, elapsed time 0.21
# [IterativeImputer] Change: 0.16745160293277195, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 12/20, elapsed time 0.23
# [IterativeImputer] Change: 0.15462534080454304, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 13/20, elapsed time 0.24
# [IterativeImputer] Change: 0.14055134035512573, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 14/20, elapsed time 0.26
# [IterativeImputer] Change: 0.1261597057680266, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 15/20, elapsed time 0.28
# [IterativeImputer] Change: 0.11207215747784538, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 16/20, elapsed time 0.29
# [IterativeImputer] Change: 0.09868657199417186, scaled tolerance: 0.098263
# [IterativeImputer] Ending imputation round 17/20, elapsed time 0.30
# [IterativeImputer] Change: 0.08624077033021038, scaled tolerance: 0.098263
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (45, 6)
# [IterativeImputer] Ending imputation round 1/20, elapsed time 0.02
# [IterativeImputer] Change: 16.419134225169522, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 2/20, elapsed time 0.03
# [IterativeImputer] Change: 6.255726080536464, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 3/20, elapsed time 0.05
# [IterativeImputer] Change: 4.3536619167975985, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 4/20, elapsed time 0.06
# [IterativeImputer] Change: 3.640808148248445, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 5/20, elapsed time 0.08
# [IterativeImputer] Change: 2.9791141547137867, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 6/20, elapsed time 0.09
# [IterativeImputer] Change: 2.4352387189254903, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 7/20, elapsed time 0.11
# [IterativeImputer] Change: 1.989783587110379, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 8/20, elapsed time 0.12
# [IterativeImputer] Change: 1.6256707118089717, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 9/20, elapsed time 0.14
# [IterativeImputer] Change: 1.328171057378586, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 10/20, elapsed time 0.16
# [IterativeImputer] Change: 1.0851131289375, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 11/20, elapsed time 0.18
# [IterativeImputer] Change: 0.8865371892871559, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 12/20, elapsed time 0.20
# [IterativeImputer] Change: 0.7243019526111114, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 13/20, elapsed time 0.21
# [IterativeImputer] Change: 0.5917558667635467, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 14/20, elapsed time 0.23
# [IterativeImputer] Change: 0.4834651612659937, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 15/20, elapsed time 0.24
# [IterativeImputer] Change: 0.3949909169986676, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 16/20, elapsed time 0.26
# [IterativeImputer] Change: 0.3227068023497903, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 17/20, elapsed time 0.27
# [IterativeImputer] Change: 0.26365020807635275, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 18/20, elapsed time 0.28
# [IterativeImputer] Change: 0.21540069295724074, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 19/20, elapsed time 0.30
# [IterativeImputer] Change: 0.17598072504926598, scaled tolerance: 0.131831
# [IterativeImputer] Ending imputation round 20/20, elapsed time 0.32
# [IterativeImputer] Change: 0.14377461719050233, scaled tolerance: 0.131831
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11928\888521308.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_handled = df_eu_p_b.groupby('Country', group_keys=False).apply(handle_missing_country)

# %%
df_handled.head()
# Out:
#       WEO_Country_Code Country  Advanced_Country  Year  BCA_NGDPD   GGR_NGDP  \
# 3330               469   Egypt                 0  1980     -0.822  22.656899
# 3331               469   Egypt                 0  1981     -4.332  22.656899
# 3332               469   Egypt                 0  1982     -6.836  22.656899
# 3333               469   Egypt                 0  1983     -3.974  22.656899
# 3334               469   Egypt                 0  1984     -8.101  22.656899
#
#       GGSB_NPGDP  GGXWDG_NGDP   GGX_NGDP       LUR  NGDP_RPCH  NGSD_NGDP  \
# 3330   -7.956689    82.852726  29.266546  9.859629      3.409     15.676
# 3331   -7.956689    82.852726  29.266546  9.859629      2.198     13.379
# 3332   -7.956689    82.852726  29.266546  9.859629      7.296     12.436
# 3333   -7.956689    82.852726  29.266546  9.859629      8.876     12.967
# 3334   -7.956689    82.852726  29.266546  9.859629      8.021     10.224
#
#       NID_NGDP  PCPIPCH  PPPEX     PPPPC  PPPSH  TM_RPCH     TRWMA  TX_RPCH
# 3330    33.994   20.500  0.187  2170.144  0.665   10.013  11.12418   13.118
# 3331    33.368   10.400  0.183  2360.617  0.666    2.505  11.12418  -10.178
# 3332    33.845   14.900  0.190  2617.817  0.711    2.926  11.12418    8.354
# 3333    28.791   15.982  0.205  2883.125  0.755    3.118  11.12418    1.987
# 3334    26.775   17.060  0.206  3139.622  0.780    7.937  11.12418    1.527

# %%
# list of variables
data_columns = cols_with_na

# countries
countries = df["Country"].unique()

n_cols = 3
n_rows = (len(data_columns) + n_cols - 1) // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, n_rows*4), constrained_layout=True)

for i, col in enumerate(data_columns):
    row, col_idx = divmod(i, n_cols)
    ax = axes[row, col_idx]

    for country_name, color in zip(countries, ['red', 'green']):
        before = df_eu_p[df_eu_p['Country'] == country_name]
        after = df_handled[df_handled['Country'] == country_name]

        ax.plot(before['Year'], before[col], 'o-', label=f'{country_name} - Before', color=color, alpha=0.5)
        ax.plot(after['Year'], after[col], '--', label=f'{country_name} - After', color=color)

    ax.set_title(f'{col} over Years', fontsize=10)
    ax.set_xlabel('Year')
    ax.set_ylabel(col)
    ax.legend(fontsize=8)
    ax.grid(True)

# Hide unused axes
for j in range(len(data_columns), n_rows * n_cols):
    fig.delaxes(axes.flatten()[j])

# Title
plt.suptitle('Time Series of All Variables (Before and After Imputation) for Egypt and United States', fontsize=16)
plt.show()

# %%
df_handled.isna().sum()
# Out:
# WEO_Country_Code    0
# Country             0
# Advanced_Country    0
# Year                0
# BCA_NGDPD           0
# GGR_NGDP            0
# GGSB_NPGDP          0
# GGXWDG_NGDP         0
# GGX_NGDP            0
# LUR                 0
# NGDP_RPCH           0
# NGSD_NGDP           0
# NID_NGDP            0
# PCPIPCH             0
# PPPEX               0
# PPPPC               0
# PPPSH               0
# TM_RPCH             0
# TRWMA               0
# TX_RPCH             0
# dtype: int64

# %%
df_handled.to_csv(folder_path+"/../02-Data_Clean_EG_US.csv",index=False)

# %% [markdown]
# # **END**
