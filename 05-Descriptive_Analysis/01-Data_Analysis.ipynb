# %% [markdown]
# ## **Project: Study On Panel Data Methodologies With Application To Macroeconometrics (Inflation Forecasting)**.
#
# > ### **Title**: Merge of Dataset.
#
#
# #### **Table of Contents:**
# <ul>
# <li><a href="#1">1. Delete countries with a large number of missing values.</a></li>
# <li><a href="#2">2. Delete years with a large number of missing values.</a></li>
# <li><a href="#3">3. Apply the interpolation to Missing Values.</a></li>
# </ul>

# %% [markdown]
# **Import Library**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import glob
import math


sns.set(rc={'figure.figsize': [15,5]}, font_scale=1.2);
pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# <a id=''></a>
#
# #### Final Dataset Table:
#
# - > E. Table for data values `WEO_Data_Countries` name Columns {'WEO_Country_Code', 'Country', 'Advanced_Country', 'Years' , and all Varibles 'WEO_Subject_Code' {'BCA_NGDPD', 'GGR_NGDP', 'GGSB_NPGDP', 'GGX_NGDP', 'GGXWDG_NGDP', 'LUR', 'NGDP_RPCH', 'NGSD_NGDP', 'NID_NGDP', 'PCPIPCH', 'PPPEX', 'PPPPC', 'PPPSH', 'TM_RPCH', 'TRWMA', 'TX_RPCH'} }

# %% [markdown]
# **Load Dataset**

# %%
df = pd.read_csv("../03-Dataset/01-Data_Clean.csv")
print(df.shape)
display(df.head())
# Out:
# (1750, 20)
#      Country  WEO_Country_Code  Advanced_Country  Year  BCA_NGDPD  GGR_NGDP  \
# 0  Argentina               213                 0  2000     -2.878    21.830
# 1  Argentina               213                 0  2001     -1.316    21.068
# 2  Argentina               213                 0  2002      7.666    19.943
# 3  Argentina               213                 0  2003      5.597    23.526
# 4  Argentina               213                 0  2004      1.798    26.996
#
#    GGSB_NPGDP  GGXWDG_NGDP  GGX_NGDP     LUR  NGDP_RPCH  NGSD_NGDP  NID_NGDP  \
# 0      -4.552       40.833    25.247  17.134     -0.789     12.459    15.337
# 1      -5.590       48.007    26.432  19.209     -4.409     12.325    13.640
# 2       1.188      147.203    21.853  22.450    -10.894     17.631     9.965
# 3       3.453      125.162    22.026  17.250      8.955     18.474    12.877
# 4       4.719      117.878    23.030  13.625      8.911     19.350    17.551
#
#    PCPIPCH  PPPEX      PPPPC  PPPSH  TM_RPCH  TRWMA  TX_RPCH
# 0   -0.939  0.639  13529.290  0.995   -2.322  10.52    1.898
# 1   -1.065  0.618  13091.488  0.929  -16.587   9.25    6.096
# 2   25.869  0.794  11733.021  0.806  -53.558  12.01    0.244
# 3   13.443  0.859  12914.244  0.847   48.953  12.87    5.006
# 4    4.416  0.887  14308.616  0.878   51.050   5.96   -0.150

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1750 entries, 0 to 1749
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           1750 non-null   object
#  1   WEO_Country_Code  1750 non-null   int64
#  2   Advanced_Country  1750 non-null   int64
#  3   Year              1750 non-null   int64
#  4   BCA_NGDPD         1750 non-null   float64
#  5   GGR_NGDP          1750 non-null   float64
#  6   GGSB_NPGDP        1750 non-null   float64
#  7   GGXWDG_NGDP       1750 non-null   float64
#  8   GGX_NGDP          1750 non-null   float64
#  9   LUR               1750 non-null   float64
#  10  NGDP_RPCH         1750 non-null   float64
#  11  NGSD_NGDP         1750 non-null   float64
#  12  NID_NGDP          1750 non-null   float64
#  13  PCPIPCH           1750 non-null   float64
#  14  PPPEX             1750 non-null   float64
#  15  PPPPC             1750 non-null   float64
#  16  PPPSH             1750 non-null   float64
#  17  TM_RPCH           1750 non-null   float64
#  18  TRWMA             1750 non-null   float64
#  19  TX_RPCH           1750 non-null   float64
# dtypes: float64(16), int64(3), object(1)
# memory usage: 273.6+ KB

# %%
df.isna().sum()
# Out:
# Country             0
# WEO_Country_Code    0
# Advanced_Country    0
# Year                0
# BCA_NGDPD           0
# GGR_NGDP            0
# GGSB_NPGDP          0
# GGXWDG_NGDP         0
# GGX_NGDP            0
# LUR                 0
# NGDP_RPCH           0
# NGSD_NGDP           0
# NID_NGDP            0
# PCPIPCH             0
# PPPEX               0
# PPPPC               0
# PPPSH               0
# TM_RPCH             0
# TRWMA               0
# TX_RPCH             0
# dtype: int64

# %%
df.describe().T
# Out:
#                    count          mean           std       min          25%  \
# WEO_Country_Code  1750.0    454.771429    322.466382   111.000    178.00000
# Advanced_Country  1750.0      0.485714      0.499939     0.000      0.00000
# Year              1750.0   2012.000000      7.213164  2000.000   2006.00000
# BCA_NGDPD         1750.0     -0.865977      6.099256   -24.068     -4.33800
# GGR_NGDP          1750.0     33.218601     11.166992    12.352     23.32075
# GGSB_NPGDP        1750.0     -2.436920      3.201662   -21.489     -4.25550
# GGXWDG_NGDP       1750.0     57.382052     36.689731     0.052     35.63825
# GGX_NGDP          1750.0     35.568684     11.402941     9.015     25.92925
# LUR               1750.0      8.488759      5.328151     0.700      5.02400
# NGDP_RPCH         1750.0      2.920472      3.818226   -28.759      1.36550
# NGSD_NGDP         1750.0     22.541346      8.167286   -76.451     17.82300
# NID_NGDP          1750.0     23.482843      5.602739     8.932     19.97900
# PCPIPCH           1750.0      5.157278     10.697971    -3.723      1.55300
# PPPEX             1750.0    130.889777    550.005941     0.016      0.65225
# PPPPC             1750.0  29144.158285  19788.011279  3230.470  13391.98575
# PPPSH             1750.0      0.978094      2.224212     0.003      0.09700
# TM_RPCH           1750.0      4.814599     10.026330   -53.558      0.30450
# TRWMA             1750.0      3.761686      3.583352     0.000      1.64000
# TX_RPCH           1750.0      4.590658      8.976608   -57.613      0.71825
#
#                          50%           75%         max
# WEO_Country_Code    285.5000    913.000000     968.000
# Advanced_Country      0.0000      1.000000       1.000
# Year               2012.0000   2018.000000    2024.000
# BCA_NGDPD            -1.3590      2.162375      30.165
# GGR_NGDP             33.9800     41.556250      63.053
# GGSB_NPGDP           -2.2120     -0.327250      11.137
# GGXWDG_NGDP          49.7970     71.753250     258.374
# GGX_NGDP             36.3735     44.567500      74.416
# LUR                   7.1735     10.062750      34.300
# NGDP_RPCH             2.9810      4.987750      24.616
# NGSD_NGDP            22.1465     26.645250      60.788
# NID_NGDP             22.8655     25.866250      68.207
# PCPIPCH               2.8615      5.561250     229.824
# PPPEX                 1.2665      9.806750    4917.825
# PPPPC             24488.9180  40951.293000  148185.776
# PPPSH                 0.3435      0.923500      20.502
# TM_RPCH               4.9595      9.995500      51.050
# TRWMA                 2.2700      4.607500      26.380
# TX_RPCH               4.2965      8.853500      72.658

# %%
df.Country.value_counts()
# Out:
# Country
# Argentina        25
# Netherlands      25
# Philippines      25
# Peru             25
# Paraguay         25
#                  ..
# Iceland          25
# Indonesia        25
# Ireland          25
# Italy            25
# United States    25
# Name: count, Length: 70, dtype: int64

# %%
df.drop(columns=["Country", "WEO_Country_Code"])
# Out:
#       Advanced_Country  Year  BCA_NGDPD  GGR_NGDP  GGSB_NPGDP  GGXWDG_NGDP  \
# 0                    0  2000     -2.878    21.830      -4.552       40.833
# 1                    0  2001     -1.316    21.068      -5.590       48.007
# 2                    0  2002      7.666    19.943       1.188      147.203
# 3                    0  2003      5.597    23.526       3.453      125.162
# 4                    0  2004      1.798    26.996       4.719      117.878
# ...                ...   ...        ...       ...         ...          ...
# 1745                 1  2020     -2.815    30.646     -10.599      131.831
# 1746                 1  2021     -3.665    31.576     -10.475      124.524
# 1747                 1  2022     -3.892    32.385      -6.526      118.617
# 1748                 1  2023     -3.266    29.211      -7.648      118.725
# 1749                 1  2024     -3.252    29.897      -7.702      121.005
#
#       GGX_NGDP     LUR  NGDP_RPCH  NGSD_NGDP  NID_NGDP  PCPIPCH  PPPEX  \
# 0       25.247  17.134     -0.789     12.459    15.337   -0.939  0.639
# 1       26.432  19.209     -4.409     12.325    13.640   -1.065  0.618
# 2       21.853  22.450    -10.894     17.631     9.965   25.869  0.794
# 3       22.026  17.250      8.955     18.474    12.877   13.443  0.859
# 4       23.030  13.625      8.911     19.350    17.551    4.416  0.887
# ...        ...     ...        ...        ...       ...      ...    ...
# 1745    44.568   8.092     -2.163     18.232    21.419    1.249  1.000
# 1746    42.599   5.350      6.055     17.613    21.333    4.682  1.000
# 1747    36.308   3.633      2.512     18.315    21.950    7.992  1.000
# 1748    36.279   3.625      2.887     17.355    21.541    4.128  1.000
# 1749    37.526   4.081      2.765     17.911    21.813    2.987  1.000
#
#           PPPPC   PPPSH  TM_RPCH  TRWMA  TX_RPCH
# 0     13529.290   0.995   -2.322  10.52    1.898
# 1     13091.488   0.929  -16.587   9.25    6.096
# 2     11733.021   0.806  -53.558  12.01    0.244
# 3     12914.244   0.847   48.953  12.87    5.006
# 4     14308.616   0.878   51.050   5.96   -0.150
# ...         ...     ...      ...    ...      ...
# 1745  64461.618  15.349   -8.979   1.52  -13.127
# 1746  71257.958  15.234   14.671   1.47    6.477
# 1747  77979.858  15.097    8.593   1.49    7.513
# 1748  82715.100  15.045   -1.172   1.49    2.764
# 1749  86601.280  14.991    4.705   1.49    2.729
#
# [1750 rows x 18 columns]

# %% [markdown]
# <a id='1'></a>
#
# ### **1. :**

# %% [markdown]
# <a id='2'></a>
#
# ### **2. :**

# %% [markdown]
# <a id='3'></a>
#
# ### **3. Apply the interpolation to Missing Values:**

# %% [markdown]
# # **END**
